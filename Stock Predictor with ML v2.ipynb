# %% [markdown]
# This code uses Technical Anlaysis Indicators to predict the price of a stock one week in the future.
#
# The program:
# * Takes the list of tickers in the "tickers" variable.
# * Downloads historical price data for each
# * Calculates Technical Indicators
# * Trains a Machine Learning model
# * Then uses the model to predict the price of each stock five trading days ahead
# * Displays a list of the top 10 best perfomers

# %% [markdown]
# Libraries:

# %%
# !pip install pandas_ta
# !sed -i 's/from numpy import NaN as npNaN/from numpy import nan as npNaN/g' /usr/local/lib/python3.11/dist-packages/pandas_ta/momentum/squeeze_pro.py
import pandas_ta as ta
import yfinance as yf
import pandas as pd
import numpy as np
import time

from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from numpy import nan as npNaN
import statsmodels.api as sm
# Out:
# Requirement already satisfied: pandas_ta in /usr/local/lib/python3.11/dist-packages (0.3.14b0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from pandas_ta) (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas_ta) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas_ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas_ta) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->pandas_ta) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->pandas_ta) (1.17.0)

# %% [markdown]
# Ticker List:

# %%
#tickers to be processed:
tickers = [ "VIST", "TSLA", "MSTR", "SPY", "BABA", "ANF", "HMY", "PLTR", "TCOM",
    "NVDA","KO", "INTC", "NU", "EWZ", "QQQ", "XLE", "PBR", "GOOGL", "GOLD", "BIOX",
    "HUT", "IBIT", "COIN", "MRNA", "MELI", "HPQ", "NIO", "GPRK", "GLD",
    "AAPL", "JD", "AMD", "VALE", "DIA", "AMZN", "GLOB", "LMT", "IWM", "META",
    "TGT", "BAK", "FXI", "AVGO", "MSFT", "MU", "JMIA", "ARKK", "PAGS", "ETHA",
    "NKE", "BBD", "SH", "RIOT", "PHG", "SATL", "AAL", "ORCL", "XLF", "ADBE",
    "ABEV", "OXY", "UPST", "BIDU", "XOM", "UBER", "C", "TSM", "QCOM", "BITF",
    "WMT", "GM", "PFE", "PAAS", "CAT", "X", "NEM", "SAN", "F", "T", "JPM",
    "CVX", "BK", "LAC", "BA", "UAL", "DISN"]

# %%
#complete list of CEDEARS tickers for reference
tikers2 = ["SPY", "BABA", "ANF", "HMY", "PLTR", "TCOM", "NVDA",
    "KO", "INTC", "NU", "EWZ", "QQQ", "XLE", "PBR", "GOOGL", "GOLD", "BIOX",
    "HUT", "IBIT", "COIN", "MRNA", "MELI", "HPQ", "NIO", "GPRK", "GLD", "BRKB",
    "AAPL", "JD", "AMD", "VALE", "DIA", "AMZN", "GLOB", "LMT", "IWM", "META",
    "TGT", "BAK", "FXI", "AVGO", "MSFT", "MU", "JMIA", "ARKK", "PAGS", "ETHA",
    "NKE", "BBD", "SH", "RIOT", "PHG", "SATL", "AAL", "ORCL", "XLF", "ADBE",
    "ABEV", "OXY", "UPST", "BIDU", "XOM", "UBER", "C", "TSM", "QCOM", "BITF",
    "WMT", "GM", "PFE", "PAAS", "CAT", "X", "NEM", "SAN", "F", "T", "JPM",
    "CVX", "BK", "LAC", "BA", "UAL", "DISN", "GGB", "PEP", "V", "JNJ",
    "EBAY", "ERJ", "MMM", "XYZ", "PYPL", "LLY", "AMAT", "ROST", "SNOW",
    "UNH", "MO", "MRK", "AZN", "PM", "LVS", "RIO", "URBN", "TXR", "WFC",
    "SHEL", "RBLX", "HAL", "TEN", "MCD", "WBA", "SUZ", "HSBC", "AMGN", "DOW",
    "SAP", "ZM", "SBUX", "XP", "CRM", "ADI", "PG", "MRVL", "GS", "TM",
    "BB", "HWM", "IBM", "VZ", "TXN", "MOS", "AXP", "TRIP", "EEM", "PSX",
    "GILD", "UL", "HOG", "MDT", "IEUR", "NFLX", "FSLR", "LAR", "ABT", "ABBV",
    "SPOT", "CL", "VEA", "SHOP", "BHP", "CAAP", "STNE", "CDE", "ITUB", "XLP",
    "SID", "YY", "HD", "AIG", "HSY", "GE", "IVE", "COST", "FMX", "MDLZ",
    "GLW", "LYG", "BBAS3", "MA", "BP", "BBV", "TIMB", "DOCU", "TTE", "BSBR",
    "NG", "STLA", "ADGO", "IVW", "NGG", "ABNB", "SNAP", "XLRE", "AEM", "SE",
    "XLK", "CSCO", "DESP", "KMB", "DEO", "XLV", "KGC", "LRCX", "ARCO", "SPGI",
    "SONY", "MUX", "AAP", "BIIB", "KOFM", "EA", "PETR3", "ACN", "HDB", "BMY",
    "PANW", "DE", "SPCE", "BKNG", "ORLY", "FDX", "PBI", "SYY", "ARM", "GFI",
    "BRFS", "HL", "MSI", "CVS", "PCAR", "ERIC", "VOD", "NUE", "IBB", "VRSN",
    "FCX", "HMC", "NVS", "ABEV3", "GSK", "XLY", "ING", "XROX", "SLB", "NTES",
    "CX", "TMUS", "TEFO", "XLC", "AMX", "PKS", "BNG", "RTX", "LND", "RACE",
    "EFX", "BCS", "ETSY", "WBO", "XLI", "DAL", "EBR", "MUFG", "NOKA", "HON",
    "SDA", "GT", "TMO", "CAR", "YELP"]

# %%
report_data = {
      'Ticker': [],
      'Latest Close Value':[],
      'Predicted Value':[],
      'Expected Return':[],
      'Precision R2':[]
      }

for i in range(0, len(tickers)):
  try:
    time.sleep(1)
    print('\nDownloading ticker: ' + tickers[i] + ' (' + str(i+1) + '/' + str(len(tickers)) + ')')
    df = yf.download(tickers[i], start="2019-01-01", progress= False)
    df = df[['Open', 'High', 'Low', 'Close', 'Volume']]

    df.columns = df.columns.droplevel(1) #Drop second level column (ticker name)

    df['Next_Week_Close'] = df['Close'].shift(-5)

    # Simple Moving Average (SMA): Average price over the last 50 periods
    df['SMA_50'] = ta.sma(df['Close'], length=50)

    # Exponential Moving Average (EMA): Weighted average that reacts faster to recent price changes, using 50 periods
    df['EMA_50'] = ta.ema(df['Close'], length=50)

    # Relative Strength Index (RSI): Momentum indicator that measures the magnitude of recent price changes to evaluate overbought/oversold conditions, using a 14-period lookback
    df['RSI'] = ta.rsi(df['Close'], length=14)

    # Moving Average Convergence Divergence (MACD): Trend-following momentum indicator, using 12 and 26 periods for the fast and slow EMAs and a 9-period signal line
    macd_df = ta.macd(df['Close'])
    # Add MACD values to your original DataFrame
    df['MACD'] = macd_df['MACD_12_26_9']        # MACD line
    df['MACD_Signal'] = macd_df['MACDs_12_26_9'] # Signal line
    df['MACD_Histogram'] = macd_df['MACDh_12_26_9'] # MACD Histogram

    # Bollinger Bands: Volatility indicator using a 20-period moving average and 2 standard deviations
    bollinger = ta.bbands(df['Close'], length=20, std=2)
    df['BB_Upper'] = bollinger['BBU_20_2.0']  # Upper Bollinger Band
    df['BB_Middle'] = bollinger['BBM_20_2.0'] # Middle Band (20-period SMA)
    df['BB_Lower'] = bollinger['BBL_20_2.0']  # Lower Bollinger Band

    # Stochastic Oscillator: Momentum indicator comparing closing prices to price ranges over 14 periods with a 3-period %D moving average
    stoch = ta.stoch(df['High'], df['Low'], df['Close'], k=14, d=3)
    df['%K'] = stoch['STOCHk_14_3_3'] # %K line (main line)
    df['%D'] = stoch['STOCHd_14_3_3'] # %D line (3-period moving average of %K)

    # Average True Range (ATR): Volatility indicator measuring the average range of price movement over the last 14 periods
    df['ATR'] = ta.atr(df['High'], df['Low'], df['Close'], length=14)

    # Drop rows with missing values due to shifting and indicator calculation
    df.dropna(inplace=True)

    scaler = MinMaxScaler()

    X = df.drop(columns=['Next_Week_Close','Open', 'High', 'Low'])
    y = df['Next_Week_Close']

    X = scaler.fit_transform(X)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

    modelSVR2 = SVR(C=2.0, degree=2, kernel='linear')
    modelSVR2.fit(X_train, y_train)
    y_test_pred2 = modelSVR2.predict(X_test)

    r2_2 = r2_score(y_test, y_test_pred2)

    latest_prediction = modelSVR2.predict(X[-1].reshape(1, -1))
    last_close_price = df['Close'].iloc[-1]
    expected_return = (latest_prediction[0] - last_close_price) / last_close_price

    report_data['Ticker'].append(tickers[i])
    report_data['Latest Close Value'].append(last_close_price)
    report_data['Expected Return'].append(expected_return * 100)
    report_data['Predicted Value'].append(latest_prediction[0])
    report_data['Precision R2'].append(r2_2 * 100)

  except Exception as e:
            print(f"Error when loading ticker {i}: {e}")
# Out:
# Downloading ticker: VIST (1/86)
#
# Downloading ticker: TSLA (2/86)
#
# Downloading ticker: MSTR (3/86)
#
# Downloading ticker: SPY (4/86)
#
# Downloading ticker: BABA (5/86)
#
# Downloading ticker: ANF (6/86)
#
# Downloading ticker: HMY (7/86)
#
# Downloading ticker: PLTR (8/86)
#
# Downloading ticker: TCOM (9/86)
#
# Downloading ticker: NVDA (10/86)
#
# Downloading ticker: KO (11/86)
#
# Downloading ticker: INTC (12/86)
#
# Downloading ticker: NU (13/86)
#
# Downloading ticker: EWZ (14/86)
#
# Downloading ticker: QQQ (15/86)
#
# Downloading ticker: XLE (16/86)
# <ipython-input-57-fe9be5b134db>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Next_Week_Close'] = df['Close'].shift(-5)
# <ipython-input-57-fe9be5b134db>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SMA_50'] = ta.sma(df['Close'], length=50)
# <ipython-input-57-fe9be5b134db>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['EMA_50'] = ta.ema(df['Close'], length=50)
# <ipython-input-57-fe9be5b134db>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['RSI'] = ta.rsi(df['Close'], length=14)
# <ipython-input-57-fe9be5b134db>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MACD'] = macd_df['MACD_12_26_9']        # MACD line
# <ipython-input-57-fe9be5b134db>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MACD_Signal'] = macd_df['MACDs_12_26_9'] # Signal line
# <ipython-input-57-fe9be5b134db>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MACD_Histogram'] = macd_df['MACDh_12_26_9'] # MACD Histogram
# <ipython-input-57-fe9be5b134db>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BB_Upper'] = bollinger['BBU_20_2.0']  # Upper Bollinger Band
# <ipython-input-57-fe9be5b134db>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BB_Middle'] = bollinger['BBM_20_2.0'] # Middle Band (20-period SMA)
# <ipython-input-57-fe9be5b134db>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BB_Lower'] = bollinger['BBL_20_2.0']  # Lower Bollinger Band
# <ipython-input-57-fe9be5b134db>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['%K'] = stoch['STOCHk_14_3_3'] # %K line (main line)
# <ipython-input-57-fe9be5b134db>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['%D'] = stoch['STOCHd_14_3_3'] # %D line (3-period moving average of %K)
# <ipython-input-57-fe9be5b134db>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ATR'] = ta.atr(df['High'], df['Low'], df['Close'], length=14)
# <ipython-input-57-fe9be5b134db>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)
# Downloading ticker: PBR (17/86)
#
# Downloading ticker: GOOGL (18/86)
#
# Downloading ticker: GOLD (19/86)
#
# Downloading ticker: BIOX (20/86)
#
# Downloading ticker: HUT (21/86)
#
# Downloading ticker: IBIT (22/86)
#
# Downloading ticker: COIN (23/86)
#
# Downloading ticker: MRNA (24/86)
#
# Downloading ticker: MELI (25/86)
#
# Downloading ticker: HPQ (26/86)
#
# Downloading ticker: NIO (27/86)
#
# Downloading ticker: GPRK (28/86)
#
# Downloading ticker: GLD (29/86)
#
# Downloading ticker: AAPL (30/86)
#
# Downloading ticker: JD (31/86)
#
# Downloading ticker: AMD (32/86)
#
# Downloading ticker: VALE (33/86)
#
# Downloading ticker: DIA (34/86)
#
# Downloading ticker: AMZN (35/86)
# <ipython-input-57-fe9be5b134db>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Next_Week_Close'] = df['Close'].shift(-5)
# <ipython-input-57-fe9be5b134db>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SMA_50'] = ta.sma(df['Close'], length=50)
# <ipython-input-57-fe9be5b134db>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['EMA_50'] = ta.ema(df['Close'], length=50)
# <ipython-input-57-fe9be5b134db>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['RSI'] = ta.rsi(df['Close'], length=14)
# <ipython-input-57-fe9be5b134db>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MACD'] = macd_df['MACD_12_26_9']        # MACD line
# <ipython-input-57-fe9be5b134db>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MACD_Signal'] = macd_df['MACDs_12_26_9'] # Signal line
# <ipython-input-57-fe9be5b134db>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MACD_Histogram'] = macd_df['MACDh_12_26_9'] # MACD Histogram
# Downloading ticker: GLOB (36/86)
#
# Downloading ticker: LMT (37/86)
#
# Downloading ticker: IWM (38/86)
#
# Downloading ticker: META (39/86)
#
# Downloading ticker: TGT (40/86)
#
# Downloading ticker: BAK (41/86)
#
# Downloading ticker: FXI (42/86)
#
# Downloading ticker: AVGO (43/86)
#
# Downloading ticker: MSFT (44/86)
#
# Downloading ticker: MU (45/86)
#
# Downloading ticker: JMIA (46/86)
#
# Downloading ticker: ARKK (47/86)
#
# Downloading ticker: PAGS (48/86)
#
# Downloading ticker: ETHA (49/86)
#
# Downloading ticker: NKE (50/86)
#
# Downloading ticker: BBD (51/86)
#
# Downloading ticker: SH (52/86)
#
# Downloading ticker: RIOT (53/86)
#
# Downloading ticker: PHG (54/86)
#
# Downloading ticker: SATL (55/86)
#
# Downloading ticker: AAL (56/86)
#
# Downloading ticker: ORCL (57/86)
#
# Downloading ticker: XLF (58/86)
#
# Downloading ticker: ADBE (59/86)
#
# Downloading ticker: ABEV (60/86)
#
# Downloading ticker: OXY (61/86)
#
# Downloading ticker: UPST (62/86)
#
# Downloading ticker: BIDU (63/86)
#
# Downloading ticker: XOM (64/86)
#
# Downloading ticker: UBER (65/86)
#
# Downloading ticker: C (66/86)
#
# Downloading ticker: TSM (67/86)
#
# Downloading ticker: QCOM (68/86)
#
# Downloading ticker: BITF (69/86)
#
# Downloading ticker: WMT (70/86)
#
# Downloading ticker: GM (71/86)
#
# Downloading ticker: PFE (72/86)
#
# Downloading ticker: PAAS (73/86)
#
# Downloading ticker: CAT (74/86)
#
# Downloading ticker: X (75/86)
#
# Downloading ticker: NEM (76/86)
#
# Downloading ticker: SAN (77/86)
#
# Downloading ticker: F (78/86)
# <ipython-input-57-fe9be5b134db>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Next_Week_Close'] = df['Close'].shift(-5)
# <ipython-input-57-fe9be5b134db>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SMA_50'] = ta.sma(df['Close'], length=50)
# <ipython-input-57-fe9be5b134db>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['EMA_50'] = ta.ema(df['Close'], length=50)
# <ipython-input-57-fe9be5b134db>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['RSI'] = ta.rsi(df['Close'], length=14)
# <ipython-input-57-fe9be5b134db>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MACD'] = macd_df['MACD_12_26_9']        # MACD line
# <ipython-input-57-fe9be5b134db>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MACD_Signal'] = macd_df['MACDs_12_26_9'] # Signal line
# <ipython-input-57-fe9be5b134db>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MACD_Histogram'] = macd_df['MACDh_12_26_9'] # MACD Histogram
# <ipython-input-57-fe9be5b134db>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BB_Upper'] = bollinger['BBU_20_2.0']  # Upper Bollinger Band
# <ipython-input-57-fe9be5b134db>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BB_Middle'] = bollinger['BBM_20_2.0'] # Middle Band (20-period SMA)
# <ipython-input-57-fe9be5b134db>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BB_Lower'] = bollinger['BBL_20_2.0']  # Lower Bollinger Band
# <ipython-input-57-fe9be5b134db>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['%K'] = stoch['STOCHk_14_3_3'] # %K line (main line)
# <ipython-input-57-fe9be5b134db>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['%D'] = stoch['STOCHd_14_3_3'] # %D line (3-period moving average of %K)
# <ipython-input-57-fe9be5b134db>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ATR'] = ta.atr(df['High'], df['Low'], df['Close'], length=14)
# <ipython-input-57-fe9be5b134db>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)
# Downloading ticker: T (79/86)
#
# Downloading ticker: JPM (80/86)
#
# Downloading ticker: CVX (81/86)
#
# Downloading ticker: BK (82/86)
#
# Downloading ticker: LAC (83/86)
#
# Downloading ticker: BA (84/86)
#
# Downloading ticker: UAL (85/86)
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DISN']: YFTzMissingError('possibly delisted; no timezone found')
# Downloading ticker: DISN (86/86)
# Error when loading ticker 85: 'NoneType' object is not subscriptable

# %%
report_data = pd.DataFrame(report_data).sort_values(by = 'Expected Return', ascending= False).reset_index(drop= True)
report_data.head(10).round(2)
# Out:
#   Ticker  Latest Close Value  Predicted Value  Expected Return  Precision R2
# 0   MRNA               34.30            37.34             8.88         96.12
# 1   GLOB              128.85           137.37             6.61         94.09
# 2   ADBE              377.84           401.96             6.38         94.85
# 3   AVGO              190.78           202.03             5.89         98.29
# 4   ETHA               13.98            14.80             5.87         84.50
# 5   COIN              177.49           187.63             5.71         94.31
# 6   TSLA              240.68           254.19             5.61         96.57
# 7   PLTR               79.62            83.56             4.95         94.63
# 8   META              590.11           618.91             4.88         98.63
# 9    UAL               69.90            72.76             4.10         97.03
